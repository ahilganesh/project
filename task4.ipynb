# %%
#Importing necessary libraries
import pandas as pd

# Load the dataset from the specified file path
file_path = r"C:\Users\Ahil\Desktop\html tot\USvideos.csv" 
df = pd.read_csv(file_path)

# Check the first few rows to ensure it's loaded correctly
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
# Checking the basic information and data types
df.info()

# Converting 'trending_date' and 'publish_time' to datetime format
df['trending_date'] = pd.to_datetime(df['trending_date'], format='%y.%d.%m')
df['publish_time'] = pd.to_datetime(df['publish_time'])

# Checking for missing values
df.isnull().sum()

# Displaying descriptive statistics of numerical columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
# Plotting distributions of 'views', 'likes', 'dislikes', and 'comment_count'
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
sns.histplot(df['views'], bins=30, kde=True, color='blue')
plt.title('Distribution of Views')

plt.subplot(2, 2, 2)
sns.histplot(df['likes'], bins=30, kde=True, color='green')
plt.title('Distribution of Likes')

plt.subplot(2, 2, 3)
sns.histplot(df['dislikes'], bins=30, kde=True, color='red')
plt.title('Distribution of Dislikes')

plt.subplot(2, 2, 4)
sns.histplot(df['comment_count'], bins=30, kde=True, color='purple')
plt.title('Distribution of Comment Count')

plt.tight_layout()  
plt.show()

# %%
# Plotting boxplots to detect outliers in the dataset
plt.figure(figsize=(14, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x=df['views'], color='blue')
plt.title('Boxplot of Views')

plt.subplot(2, 2, 2)
sns.boxplot(x=df['likes'], color='green')
plt.title('Boxplot of Likes')

plt.subplot(2, 2, 3)
sns.boxplot(x=df['dislikes'], color='red')
plt.title('Boxplot of Dislikes')

plt.subplot(2, 2, 4)
sns.boxplot(x=df['comment_count'], color='purple')
plt.title('Boxplot of Comment Count')

plt.tight_layout()
plt.show()

# %%
# Plotting the correlation heatmap
corr = df[['views', 'likes', 'dislikes', 'comment_count']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Scatter plots to explore relationships between variables
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x='views', y='likes', data=df, color='blue')
plt.title('Views vs Likes')

plt.subplot(1, 2, 2)
sns.scatterplot(x='views', y='dislikes', data=df, color='red')
plt.title('Views vs Dislikes')

plt.tight_layout()
plt.show()

# %%
# Extract the hour from the 'publish_time' to explore trends based on time of day
df['publish_hour'] = df['publish_time'].dt.hour

# Plotting distribution of views by the publish hour
plt.figure(figsize=(10, 6))
sns.lineplot(x='publish_hour', y='views', data=df)
plt.title('Views vs Publish Hour')
plt.show()
